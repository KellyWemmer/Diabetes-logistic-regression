# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#https://www.kaggle.com/kandij/diabetes-dataset?select=diabetes2.csv
#https://data.world/data-society/pima-indians-diabetes-database
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
#     https://towardsdatascience.com/end-to-end-data-science-example-predicting-diabetes-with-logistic-regression-db9bc88b4d16
#     Pregnancies: Number of times pregnant
#     Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
#     BloodPressure: Diastolic blood pressure (mm Hg)
#     SkinThickness: Triceps skin fold thickness (mm)
#     Insulin: 2-Hour serum insulin (mu U/ml)
#     BMI: Body mass index (weight in kg/(height in m)2)
#     DiabetesPedigreeFunction: Diabetes pedigree function (a function which scores likelihood of diabetes based on family history)
#     Age: Age (years)
#     Outcome: Class variable (0 if non-diabetic, 1 if diabetic)

# %% [markdown]
# ## EXPLORE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# ### There is no null data in this dataframe

# %%
#Countplot for outcome of diabetes
sns.countplot(x='Outcome', data=data)

# %%
sns.countplot('Pregnancies', data=data);

# %%
data['Glucose'].hist(bins=100, figsize=(12,8));
#There are glucose results of zero

# %%
data['BloodPressure'].hist(bins=50, figsize=(12,8));
#There are over 30 instances where blood pressure is zero

# %%
data['SkinThickness'].hist(bins=10);

# %%
data['Insulin'].hist(bins=15, figsize=(12,8));

# %%
data.query('Insulin == 0').count()
# Out:
# Pregnancies                 374
# Glucose                     374
# BloodPressure               374
# SkinThickness               374
# Insulin                     374
# BMI                         374
# DiabetesPedigreeFunction    374
# Age                         374
# Outcome                     374
# dtype: int64

# %%
data['BMI'].hist();

# %%
data.query('BMI == 0').count()
# Out:
# Pregnancies                 11
# Glucose                     11
# BloodPressure               11
# SkinThickness               11
# Insulin                     11
# BMI                         11
# DiabetesPedigreeFunction    11
# Age                         11
# Outcome                     11
# dtype: int64

# %%
data['DiabetesPedigreeFunction'].hist();

# %%
data['Age'].hist();

# %%
data.query('Age == 0').count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### The dataframe has zero values for Glucose, Blood Pressure, Insulin, BMI

# %%
data['Glucose'].replace(0,data['Glucose'].mean(axis=0),inplace=True)

# %%
data.query('Glucose == 0').count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data['BloodPressure'].replace(0,data['BloodPressure'].mean(axis=0), inplace=True)

# %%
data.query('BloodPressure == 0').count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data['Insulin'].replace(0, data['Insulin'].mean(axis=0), inplace=True)

# %%
data.query('Insulin == 0').count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data['BMI'].replace(0, data['BMI'].mean(axis=0), inplace=True)

# %%
data.query('BMI == 0').count()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.pairplot(data=data, hue='Outcome', diag_kind='hist');

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(data.corr(), annot=True);

# %% [markdown]
# ### There is significant correlation between the outcome with:
# Glucose, BMI, Age, and Pregnancies
#
# ### There are also significant correlations between:
# Pregnancies: Age, Blood Pressure
#
# Glucose: Age, BMI, Insulin, Blood Pressure
#
# Blood Pressure: Age, BMI
#
# Skin Thickness: BMI, Insulin

# %% [markdown]
# ## Train Test Split
